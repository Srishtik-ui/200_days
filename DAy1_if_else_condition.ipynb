# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishtik-ui/200_days/blob/main/DAy1_if_else_condition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a program to check whether a number is positive, negative, or zero.
n = int(input("Enter the number :"))
if(n > 0):
  print("Number is positive")
elif(n<0):
  print("Number is negative ")

else:
  print("Number is zero")
# Out:
# Enter the number :4
# Number is positive

# %%
#Write a program to check whether a number is even or odd.

n = int(input("Enter the number:"))

if n % 2 ==0:
  print("Number is even:")
else:
  print("Number is Odd")
# Out:
# Enter the number:5
# Number is Odd

# %%
#Take age as input and check if a person is eligible to vote (age ≥ 18).

n = int(input("Enter the age of person:"))
if(n < 18):
  print("Person is not eligible for vote")
else:
  print("person is eligible for vote")
# Out:
# Enter the age of person:77
# person is eligible for vote

# %%
# Take two numbers as input and print the largest number.
a = int(input("Enter the 1st number:"))
b = int(input("Enter the 2nd number:"))

if a > b:
  print("A is largest:")

else:
  print("B is largest:")
# Out:
# Enter the 1st number:2
# Enter the 2nd number:42
# B is largest:

# %%
#Take three numbers and print the greatest among them using if-elif-else.

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if num1 >= num2 and num1 >= num3:
    print("The greatest number is:", num1)
elif num2 >= num1 and num2 >= num3:
    print("The greatest number is:", num2)
else:
    print("The greatest number is:", num3)
# Out:
# Enter first number: 2
# Enter second number: 4
# Enter third number: 6
# The greatest number is: 6.0

# %%
""" Write a program to assign grades based on marks:

90–100 → A

75–89 → B

50–74 → C

Below 50 → Fail """

n = int(input("Enter the Number :"))
if (n >= 90):
  print("Grade is A")
elif(n >= 75):
  print("Grade is B")

elif(n >= 50):
  print("Grade is C")

else:
  print("Fail")
# Out:
# Enter the Number :45
# Fail

# %%
# Check whether a given year is a leap year.

n = int(input("Enter the year :"))
if n % 4 == 0 :
  print("Year is leap year:")

else:
  print("Not leap year")
# Out:
# Enter the year :3004
# Year is leap year:

# %%
# Create a calculator using if-elif-else that performs addition, subtraction, multiplication, and division based on user choice
print("Calculator")
a = float(input("Enter the 1st value:"))
b = float(input("Enter the 2nd value:"))
print("\n Choose your Operation:")
print("1. Addition")
print("2. Substraction")
print("3. Multiplication")
print("4. Division")
choice = input("Enter the choice (1/2/3/4):")

if choice == '1':
  print(a+b)

elif choice == '2':
  print(a-b)

elif choice == '3':
  print(a*b)

elif choice == '4':
  if b != 0:
        print("Result:", a / b )
  else:
        print("Error! Division by zero is not allowed.")
else:
  print("Invalid input")
# Out:
# Calculator
# Enter the 1st value:44
# Enter the 2nd value:54
#
#  Choose your Operation:
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# Enter the choice (1/2/3/4):4
# Result: 0.8148148148148148

# %%
""" 9.Take three sides as input and check whether the triangle is:

Equilateral

Isosceles

Scalene"""
a = int(input("Enter the 1st side of triangle:"))
b = int(input("Enter the 2nd side of triangle:"))
c = int(input("Enter the 3rd side of triangle:"))

if a == b == c:
  print("Triangle is Equilateral")

elif a==b or b == c or c== a:
  print("Triangle is Isosceles")

else:
  print("Triangle is Scalene")
# Out:
# Enter the 1st side of triangle:2
# Enter the 2nd side of triangle:2
# Enter the 3rd side of triangle:2
# Triangle is Equilateral

# %%
import re

"""Write a program to check whether a password is valid:
Conditions:

Minimum 8 characters

Must contain at least one digit

Must contain at least one uppercase letter """

def is_password_valid(password):

    if len(password) < 8:
        return False


    if not any(char.isdigit() for char in password):
        return False


    if not any(char.isupper() for char in password):
        return False

    return True


password_input = input("Enter the PASSWORD: ")

if is_password_valid(password_input):
    print("Password is valid")
else:
    print("Password is not valid")
# Out:
# Enter the PASSWORD: Amrit
# Password is not valid
